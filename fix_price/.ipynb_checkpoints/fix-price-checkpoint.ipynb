# %%
import pymongo
from pymongo import MongoClient
import pandas as pd
import numpy as np
import dateutil.parser
import datetime
pd.set_option("display.width", 3000)
pd.set_option("max_colwidth", -1)

client=MongoClient('localhost',27017)
db = client.shop_fix_price
final_4=db.final_4
dictionary={}

data = db.final_4.find({},{'_id':0})




for i in list(data):
    dictionary = {**dictionary, **i}

final={}

links = []
goods = {}
dates =[]

for dict_i in dictionary.values():
    dates = (list(dict_i.keys())[1:])
    links.append(dict_i["link"])

for date in dates:
    final[date] = []
    for dict_i in dictionary.values():
        final[date].append(dict_i[date])
     
    
final["Categories"]=list(dictionary.keys())
final["Links"]= list(links)

df = pd.DataFrame.from_dict(final)
df.index+=1
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          16-01-2020                     Categories                                                                       Links
# 1    {'https://fix-price,ru/product/1003023/': 77.0, 'https://fix-price,ru/product/1011016/': 27.5, 'https://fix-price,ru/product/1003025/': 25.0, 'https://fix-price,ru/product/1003024/': 25.0, 'https://fix-price,ru/product/1003032/': 25.0, 'https://fix-price,ru/product/1003018/': 27.5, 'https://fix-price,ru/product/1030033/': 27.5, 'https://fix-price,ru/product/1030017/': 50.0, 'https://fix-price,ru/product/1003028/': 18.3, 'https://fix-price,ru/product/1003030/': 50.0, 'https://fix-price,ru/product/1003029/': 18.3, 'https://fix-price,ru/product/1003031/': 18.3, 'https://fix-price,ru/product/1003027/': 18.3, 'https://fix-price,ru/product/1003026/': 18.3, 'https://fix-price,ru/product/1025094/': 27.5, 'https://fix-price,ru/product/1024196/': 12.5, 'https://fix-price,ru/product/1024189/': 27.5, 'https://fix-price,ru/product/1024188/': 27.5, 'https://fix-price,ru/product/1024203/': 10.0, 'https://fix-price,ru/product/1024200/': 9.1, 'https://fix-price,ru/product/1024206/': 10.0}      Молочные продукты              https://fix-price.ru/catalog/produkty-i-napitki/molochnye-produkty/
# 2    {'https://fix-price,ru/product/1050085/': 25.0, 'https://fix-price,ru/product/1050083/': 25.0, 'https://fix-price,ru/product/1050082/': 25.0, 'https://fix-price,ru/product/1050118/': 16.6, 'https://fix-price,ru/product/1050112/': 25.0, 'https://fix-price,ru/product/1050081/': 50.0, 'https://fix-price,ru/product/1050075/': 16.6, 'https://fix-price,ru/product/1050084/': 25.0, 'https://fix-price,ru/product/1050076/': 16.6, 'https://fix-price,ru/product/1050051/': 25.0, 'https://fix-price,ru/product/1050113/': 50.0, 'https://fix-price,ru/product/1050148/': 50.0, 'https://fix-price,ru/product/1050120/': 50.0, 'https://fix-price,ru/product/1050143/': 18.3, 'https://fix-price,ru/product/1050126/': 50.0, 'https://fix-price,ru/product/1050109/': 27.5, 'https://fix-price,ru/product/1050127/': 16.6, 'https://fix-price,ru/product/1050092/': 50.0, 'https://fix-price,ru/product/1050136/': 50.0, 'https://fix-price,ru/product/1050137/': 50.0}                                                    Мороженое                      https://fix-price.ru/catalog/produkty-i-napitki/morozhenoe/
# 3    {'https://fix-price,ru/product/1167290/': 99.0, 'https://fix-price,ru/product/1166141/': 77.0}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Колбасная продукция            https://fix-price.ru/catalog/produkty-i-napitki/kolbasnaya-produktsiya/
# 4    {'https://fix-price,ru/product/1911016/': 77.0, 'https://fix-price,ru/product/1932150/': 199.0, 'https://fix-price,ru/product/1933105/': 77.0, 'https://fix-price,ru/product/1900165/': 199.0, 'https://fix-price,ru/product/1900175/': 55.0, 'https://fix-price,ru/product/1950171/': 50.0, 'https://fix-price,ru/product/1913001/': 16.6, 'https://fix-price,ru/product/1901020/': 55.0, 'https://fix-price,ru/product/1933080/': 50.0, 'https://fix-price,ru/product/1913000/': 16.6, 'https://fix-price,ru/product/1910084/': 27.5, 'https://fix-price,ru/product/2030195/': 55.0, 'https://fix-price,ru/product/1920150/': 55.0, 'https://fix-price,ru/product/1932136/': 27.5, 'https://fix-price,ru/product/1921021/': 25.0, 'https://fix-price,ru/product/1922042/': 50.0, 'https://fix-price,ru/product/1700010/': 27.5, 'https://fix-price,ru/product/1962043/': 55.0, 'https://fix-price,ru/product/1910086/': 99.0, 'https://fix-price,ru/product/1902107/': 27.5, 'https://fix-price,ru/product/1910070/': 25.0}   Кондитерские изделия           https://fix-price.ru/catalog/produkty-i-napitki/konditerskie-izdeliya/
# 5    {'https://fix-price,ru/product/1170013/': 99.0, 'https://fix-price,ru/product/1173052/': 27.5, 'https://fix-price,ru/product/1173039/': 27.5, 'https://fix-price,ru/product/1171037/': 25.0, 'https://fix-price,ru/product/1170006/': 27.5, 'https://fix-price,ru/product/1173041/': 27.5, 'https://fix-price,ru/product/1170012/': 27.5, 'https://fix-price,ru/product/1173057/': 27.5}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Консервация мясная             https://fix-price.ru/catalog/produkty-i-napitki/konservatsiya-myasnaya/
# ..                                                                                                                                                                                                                                                                                                                                                                                        ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...                                                                                 ...
# 98   {'https://fix-price,ru/product/5014026/': 50.0, 'https://fix-price,ru/product/5014005/': 50.0, 'https://fix-price,ru/product/5014022/': 55.0, 'https://fix-price,ru/product/5014043/': 99.0, 'https://fix-price,ru/product/5014027/': 50.0, 'https://fix-price,ru/product/5014023/': 55.0, 'https://fix-price,ru/product/5014044/': 99.0, 'https://fix-price,ru/product/5014003/': 50.0, 'https://fix-price,ru/product/5014001/': 50.0}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Батарейки                      https://fix-price.ru/catalog/elektrotovary/batareyki/
# 99   {'https://fix-price,ru/product/5013083/': 55.0, 'https://fix-price,ru/product/5013206/': 77.0, 'https://fix-price,ru/product/5012111/': 50.0, 'https://fix-price,ru/product/5013044/': 55.0, 'https://fix-price,ru/product/5013077/': 99.0, 'https://fix-price,ru/product/5013097/': 50.0, 'https://fix-price,ru/product/5013079/': 77.0, 'https://fix-price,ru/product/5013174/': 199.0, 'https://fix-price,ru/product/5013074/': 50.0, 'https://fix-price,ru/product/5013178/': 77.0}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Аксессуары для телефонов и ПК  https://fix-price.ru/catalog/elektrotovary/aksessuary-dlya-telefonov-i-pk/
# 100  {'https://fix-price,ru/product/6030171/': 77.0, 'https://fix-price,ru/product/6030165/': 99.0, 'https://fix-price,ru/product/6030098/': 55.0, 'https://fix-price,ru/product/6030089/': 77.0, 'https://fix-price,ru/product/6030083/': 99.0, 'https://fix-price,ru/product/5012134/': 50.0, 'https://fix-price,ru/product/6010058/': 99.0, 'https://fix-price,ru/product/5006122/': 77.0, 'https://fix-price,ru/product/6030062/': 50.0, 'https://fix-price,ru/product/6030138/': 199.0, 'https://fix-price,ru/product/6030169/': 77.0, 'https://fix-price,ru/product/6030100/': 55.0, 'https://fix-price,ru/product/6020027/': 50.0, 'https://fix-price,ru/product/6010048/': 50.0, 'https://fix-price,ru/product/6010057/': 55.0, 'https://fix-price,ru/product/6020007/': 50.0, 'https://fix-price,ru/product/6030096/': 50.0, 'https://fix-price,ru/product/6030140/': 199.0, 'https://fix-price,ru/product/6010060/': 199.0, 'https://fix-price,ru/product/6040017/': 50.0, 'https://fix-price,ru/product/6040011/': 55.0}  Автотовары                     https://fix-price.ru/catalog/avto-moto-velo/avtotovary/
# 101  {'https://fix-price,ru/product/5410065/': 55.0, 'https://fix-price,ru/product/5410067/': 99.0, 'https://fix-price,ru/product/3105085/': 77.0, 'https://fix-price,ru/product/3105087/': 77.0, 'https://fix-price,ru/product/3105084/': 13.7}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Туризм                         https://fix-price.ru/catalog/sport-i-otdykh/turizm/
# 102  {'https://fix-price,ru/product/5400132/': 99.0, 'https://fix-price,ru/product/5400158/': 199.0, 'https://fix-price,ru/product/5400159/': 199.0}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Спорт                          https://fix-price.ru/catalog/sport-i-otdykh/sport/
#
# [102 rows x 3 columns]
